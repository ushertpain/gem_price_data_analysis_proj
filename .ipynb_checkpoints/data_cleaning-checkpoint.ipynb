# %%
import pandas as pd
import numpy as np

# %%
raw_df = pd.read_csv('Gemstone_raw_data.csv')
df = raw_df.copy()

# %%
df.head()
# Out:
#                                                Title           Dimension (mm)  \
# 0  *RARE* 14.15Cts Color Change Natural Bi-Color ...  16.200 x 12.300 x 9.180
# 1     0.74Cts Natural Black Diamond Round Cut Africa    3.950 x 3.950 x 5.190
# 2  Extremely Rare 0.69Cts Natural Color Shifting ...    5.900 x 5.900 x 3.940
# 3  PRETTY 2.40Cts Candy Pink Natural Topaz Concav...    8.000 x 8.000 x 5.200
# 4  CUSTOM CUT 3.28Cts Natural Golden Orange Citri...   10.700 x 7.500 x 6.000
#
#    Weight (cts) Certified Gemstones        Treatment Clarity     Type  \
# 0         14.15                 NaN     No Treatment      VS  Faceted
# 1          0.74                 NaN       Irradiated      VS  Faceted
# 2          0.69                 NaN     No Treatment      VS  Faceted
# 3          2.40                 NaN  Surface Coating     VVS  Faceted
# 4          3.28                 NaN     No Treatment     VVS  Faceted
#
#                        Shape Price Estimated RRP
# 0                  Octagonal   NaN           NaN
# 1                      Round   NaN           NaN
# 2                      Round   NaN           NaN
# 3                      Round   NaN           NaN
# 4  Emerald, Fancy, Octagonal   NaN           NaN

# %% [markdown]
# # Cleaning the dataset

# %%
df.shape
# Out:
# (2837, 10)

# %% [markdown]
# ### Removing Duplicates

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (2590, 10)

# %% [markdown]
# ### Removing null values in Price column

# %%
df = df[df['Price'].notna()]
df.shape
# Out:
# (2400, 10)

# %%
df.head()
# Out:
#                                                 Title  \
# 15  21.25 Cts Natural Swiss Blue Topaz Cushion Cut...
# 16    24.56 Cts Natural Swiss Blue Topaz Pear Cut USA
# 17    37.61 Cts Natural Swiss Blue Topaz Pear Cut USA
# 18    27.91 Cts Natural Swiss Blue Topaz Pear Cut USA
# 19    29.78 Cts Natural Swiss Blue Topaz Pear Cut USA
#
#               Dimension (mm)  Weight (cts) Certified Gemstones   Treatment  \
# 15  14.620 x 13.680 x 11.910         21.25                 NaN  Irradiated
# 16  21.640 x 14.000 x 10.980         24.56                 NaN  Irradiated
# 17  19.780 x 18.050 x 13.930         37.61                 NaN  Irradiated
# 18  25.560 x 13.790 x 10.520         27.91                 NaN  Irradiated
# 19  25.500 x 14.800 x 10.850         29.78                 NaN  Irradiated
#
#    Clarity     Type    Shape    Price Estimated RRP
# 15     VVS  Faceted  Cushion  170.00         299.00
# 16     VVS  Faceted     Pear  199.00         399.00
# 17     VVS  Faceted     Pear  300.00         499.00
# 18     VVS  Faceted     Pear  225.00         399.00
# 19     VVS  Faceted     Pear  240.00         449.00

# %% [markdown]
# ### Data types checking

# %%
df.dtypes
# Out:
# Title                   object
# Dimension (mm)          object
# Weight (cts)           float64
# Certified Gemstones     object
# Treatment               object
# Clarity                 object
# Type                    object
# Shape                   object
# Price                   object
# Estimated RRP           object
# dtype: object

# %%
#Price and maybe the Estimated RRP has "," value since its a price data.
#I will remove the "," first so I can change it to float dtype
df['Price'] = df['Price'].str.replace(',', '')
df['Estimated RRP'] = df['Estimated RRP'].str.replace(',', '')

# %%
#changing this column dtype now to float
df['Price'] = df['Price'].astype(float).round(2)
df['Estimated RRP'] = df['Estimated RRP'].astype(float).round(2)

# %%
df.dtypes
# Out:
# Title                   object
# Dimension (mm)          object
# Weight (cts)           float64
# Certified Gemstones     object
# Treatment               object
# Clarity                 object
# Type                    object
# Shape                   object
# Price                  float64
# Estimated RRP          float64
# dtype: object

# %% [markdown]
# ### Creating 3 new columns to get the length, width, and height from 'Dimension (mm)' column.

# %%
df.insert(2, 'Length (mm)', "")
df.insert(3, 'Width (mm)', "")
df.insert(4, 'Height (mm)', "")
df.head()
# Out:
#                                                 Title  \
# 15  21.25 Cts Natural Swiss Blue Topaz Cushion Cut...
# 16    24.56 Cts Natural Swiss Blue Topaz Pear Cut USA
# 17    37.61 Cts Natural Swiss Blue Topaz Pear Cut USA
# 18    27.91 Cts Natural Swiss Blue Topaz Pear Cut USA
# 19    29.78 Cts Natural Swiss Blue Topaz Pear Cut USA
#
#               Dimension (mm) Length (mm) Width (mm) Height (mm)  Weight (cts)  \
# 15  14.620 x 13.680 x 11.910                                            21.25
# 16  21.640 x 14.000 x 10.980                                            24.56
# 17  19.780 x 18.050 x 13.930                                            37.61
# 18  25.560 x 13.790 x 10.520                                            27.91
# 19  25.500 x 14.800 x 10.850                                            29.78
#
#    Certified Gemstones   Treatment Clarity     Type    Shape  Price  \
# 15                 NaN  Irradiated     VVS  Faceted  Cushion  170.0
# 16                 NaN  Irradiated     VVS  Faceted     Pear  199.0
# 17                 NaN  Irradiated     VVS  Faceted     Pear  300.0
# 18                 NaN  Irradiated     VVS  Faceted     Pear  225.0
# 19                 NaN  Irradiated     VVS  Faceted     Pear  240.0
#
#     Estimated RRP
# 15          299.0
# 16          399.0
# 17          499.0
# 18          399.0
# 19          449.0

# %%
#remove first the space char from Dimension
no_space_dim = df['Dimension (mm)'].apply(lambda x: x.replace(' ', ''))

# %%
#add values to the three new columns
df['Length (mm)'] = no_space_dim.apply(lambda x: x.split('x')[0])
df['Width (mm)'] = no_space_dim.apply(lambda x: x.split('x')[1])
df['Height (mm)'] = no_space_dim.apply(lambda x: x.split('x')[2])
df.head()
# Out:
#                                                 Title  \
# 15  21.25 Cts Natural Swiss Blue Topaz Cushion Cut...
# 16    24.56 Cts Natural Swiss Blue Topaz Pear Cut USA
# 17    37.61 Cts Natural Swiss Blue Topaz Pear Cut USA
# 18    27.91 Cts Natural Swiss Blue Topaz Pear Cut USA
# 19    29.78 Cts Natural Swiss Blue Topaz Pear Cut USA
#
#               Dimension (mm) Length (mm) Width (mm) Height (mm)  Weight (cts)  \
# 15  14.620 x 13.680 x 11.910      14.620     13.680      11.910         21.25
# 16  21.640 x 14.000 x 10.980      21.640     14.000      10.980         24.56
# 17  19.780 x 18.050 x 13.930      19.780     18.050      13.930         37.61
# 18  25.560 x 13.790 x 10.520      25.560     13.790      10.520         27.91
# 19  25.500 x 14.800 x 10.850      25.500     14.800      10.850         29.78
#
#    Certified Gemstones   Treatment Clarity     Type    Shape  Price  \
# 15                 NaN  Irradiated     VVS  Faceted  Cushion  170.0
# 16                 NaN  Irradiated     VVS  Faceted     Pear  199.0
# 17                 NaN  Irradiated     VVS  Faceted     Pear  300.0
# 18                 NaN  Irradiated     VVS  Faceted     Pear  225.0
# 19                 NaN  Irradiated     VVS  Faceted     Pear  240.0
#
#     Estimated RRP
# 15          299.0
# 16          399.0
# 17          499.0
# 18          399.0
# 19          449.0

# %%
#change the format of the data type of the new 3 columns
df['Length (mm)'] = df['Length (mm)'].astype(float).round(3)
df['Width (mm)'] = df['Width (mm)'].astype(float).round(3)
df['Height (mm)'] = df['Height (mm)'].astype(float).round(3)
df.dtypes
# Out:
# Title                   object
# Dimension (mm)          object
# Length (mm)            float64
# Width (mm)             float64
# Height (mm)            float64
# Weight (cts)           float64
# Certified Gemstones     object
# Treatment               object
# Clarity                 object
# Type                    object
# Shape                   object
# Price                  float64
# Estimated RRP          float64
# dtype: object

# %% [markdown]
# ### Creating a Color, Gem_type column and gets it value from Title

# %%
df.insert(5, 'Color', "")
df.insert(6, 'Gem_type', "")
df.head()
# Out:
#                                                 Title  \
# 15  21.25 Cts Natural Swiss Blue Topaz Cushion Cut...
# 16    24.56 Cts Natural Swiss Blue Topaz Pear Cut USA
# 17    37.61 Cts Natural Swiss Blue Topaz Pear Cut USA
# 18    27.91 Cts Natural Swiss Blue Topaz Pear Cut USA
# 19    29.78 Cts Natural Swiss Blue Topaz Pear Cut USA
#
#               Dimension (mm)  Length (mm)  Width (mm)  Height (mm) Color  \
# 15  14.620 x 13.680 x 11.910        14.62       13.68        11.91
# 16  21.640 x 14.000 x 10.980        21.64       14.00        10.98
# 17  19.780 x 18.050 x 13.930        19.78       18.05        13.93
# 18  25.560 x 13.790 x 10.520        25.56       13.79        10.52
# 19  25.500 x 14.800 x 10.850        25.50       14.80        10.85
#
#    Gem_type  Weight (cts) Certified Gemstones   Treatment Clarity     Type  \
# 15                  21.25                 NaN  Irradiated     VVS  Faceted
# 16                  24.56                 NaN  Irradiated     VVS  Faceted
# 17                  37.61                 NaN  Irradiated     VVS  Faceted
# 18                  27.91                 NaN  Irradiated     VVS  Faceted
# 19                  29.78                 NaN  Irradiated     VVS  Faceted
#
#       Shape  Price  Estimated RRP
# 15  Cushion  170.0          299.0
# 16     Pear  199.0          399.0
# 17     Pear  300.0          499.0
# 18     Pear  225.0          399.0
# 19     Pear  240.0          449.0

# %%
#create a function to fitch color
def get_color(title):
    if 'red' in title.lower():
        return 'red'
    elif 'yellow' in title.lower():
        return 'yellow'
    elif 'orange' in title.lower():
        return 'orange'
    elif 'cyan' in title.lower():
        return 'cyan'
    elif 'green' in title.lower():
        return 'green'
    elif 'blue' in title.lower():
        return 'blue'
    elif 'pink' in title.lower():
        return 'pink'
    elif 'purple' in title.lower():
        return 'purple'
    else:
        return 'natural'

# %%
#create a list of gem type, then create the function to fitch its gem type

gem_type = ['alexandrite', 'amethyst', 'ametrine', 'andesine feldspar', 'apatite', 'aquamarine', 'beads', 'beryl',
    'cabochons', 'calcite', 'chalcedony', 'chrome diopside', 'chrysoberyl', 'chrysoprase', 'citrine', 'colored diamonds',
    'coral', 'danburite', 'diaspore', 'emerald', 'fossickers delight', 'garnet', 'gemstone garvings', 'heliodor',
    'iolite', 'jade', 'kunzite', 'kyanite', 'mexican fire opal', 'mineral specimens', 'moonstone', 'morganite',
    'pairs', 'parcels', 'pearls', 'peridot', 'prasiolite', 'prehnite', 'quartz', 'rare gemstones', 'rhodochrosite',
    'rose quartz', 'ruby', 'ruby composite', 'sapphire', 'sapphire composites', 'scapolite', 'sillimanite', 
    'sphalerite', 'sphene', 'spinel', 'sugilite', 'sunstone', 'tanzanite', 'topaz', 'tourmaline', 'turquoise', 'zircon', 'fluorite']

def get_gem_type(title):
    for gem in gem_type:
        if gem in title.lower():
             return gem
    return 'na'

# %%
#assign values to the Color column.
df['Color'] = df['Title'].apply(get_color)
df.head(10)
# Out:
#                                                 Title  \
# 15  21.25 Cts Natural Swiss Blue Topaz Cushion Cut...
# 16    24.56 Cts Natural Swiss Blue Topaz Pear Cut USA
# 17    37.61 Cts Natural Swiss Blue Topaz Pear Cut USA
# 18    27.91 Cts Natural Swiss Blue Topaz Pear Cut USA
# 19    29.78 Cts Natural Swiss Blue Topaz Pear Cut USA
# 20    38.27 Cts Natural Swiss Blue Topaz Pear Cut USA
# 21    23.07 Cts Natural Swiss Blue Topaz Pear Cut USA
# 22    20.36 Cts Natural Swiss Blue Topaz Pear Cut USA
# 24  12.41 Cts Dazzling Natural Blue - Zircon - Cam...
# 25  3.84 Cts Fanta Orange Natural Spessartite Garn...
#
#               Dimension (mm)  Length (mm)  Width (mm)  Height (mm)   Color  \
# 15  14.620 x 13.680 x 11.910        14.62       13.68        11.91    blue
# 16  21.640 x 14.000 x 10.980        21.64       14.00        10.98    blue
# 17  19.780 x 18.050 x 13.930        19.78       18.05        13.93    blue
# 18  25.560 x 13.790 x 10.520        25.56       13.79        10.52    blue
# 19  25.500 x 14.800 x 10.850        25.50       14.80        10.85    blue
# 20  25.610 x 16.380 x 12.240        25.61       16.38        12.24    blue
# 21  23.710 x 12.770 x 10.890        23.71       12.77        10.89    blue
# 22  21.790 x 12.200 x 10.120        21.79       12.20        10.12    blue
# 24   14.100 x 14.100 x 7.250        14.10       14.10         7.25    blue
# 25     8.830 x 7.350 x 6.380         8.83        7.35         6.38  orange
#
#    Gem_type  Weight (cts) Certified Gemstones     Treatment Clarity     Type  \
# 15                  21.25                 NaN    Irradiated     VVS  Faceted
# 16                  24.56                 NaN    Irradiated     VVS  Faceted
# 17                  37.61                 NaN    Irradiated     VVS  Faceted
# 18                  27.91                 NaN    Irradiated     VVS  Faceted
# 19                  29.78                 NaN    Irradiated     VVS  Faceted
# 20                  38.23                 NaN    Irradiated     VVS  Faceted
# 21                  23.07                 NaN    Irradiated     VVS  Faceted
# 22                  20.36                 NaN    Irradiated     VVS  Faceted
# 24                  12.41                 NaN           NaN      VS  Faceted
# 25                   3.84                 NaN  No Treatment      VS  Faceted
#
#        Shape   Price  Estimated RRP
# 15   Cushion   170.0          299.0
# 16      Pear   199.0          399.0
# 17      Pear   300.0          499.0
# 18      Pear   225.0          399.0
# 19      Pear   240.0          449.0
# 20      Pear   305.0          499.0
# 21      Pear   189.0          249.0
# 22      Pear   165.0          249.0
# 24  Triangle  1150.0         2500.0
# 25      Oval   190.0            NaN

# %%
#put values to Gem_type column
df['Gem_type'] = df['Title'].apply(get_gem_type)
df.head(10)
# Out:
#                                                 Title  \
# 15  21.25 Cts Natural Swiss Blue Topaz Cushion Cut...
# 16    24.56 Cts Natural Swiss Blue Topaz Pear Cut USA
# 17    37.61 Cts Natural Swiss Blue Topaz Pear Cut USA
# 18    27.91 Cts Natural Swiss Blue Topaz Pear Cut USA
# 19    29.78 Cts Natural Swiss Blue Topaz Pear Cut USA
# 20    38.27 Cts Natural Swiss Blue Topaz Pear Cut USA
# 21    23.07 Cts Natural Swiss Blue Topaz Pear Cut USA
# 22    20.36 Cts Natural Swiss Blue Topaz Pear Cut USA
# 24  12.41 Cts Dazzling Natural Blue - Zircon - Cam...
# 25  3.84 Cts Fanta Orange Natural Spessartite Garn...
#
#               Dimension (mm)  Length (mm)  Width (mm)  Height (mm)   Color  \
# 15  14.620 x 13.680 x 11.910        14.62       13.68        11.91    blue
# 16  21.640 x 14.000 x 10.980        21.64       14.00        10.98    blue
# 17  19.780 x 18.050 x 13.930        19.78       18.05        13.93    blue
# 18  25.560 x 13.790 x 10.520        25.56       13.79        10.52    blue
# 19  25.500 x 14.800 x 10.850        25.50       14.80        10.85    blue
# 20  25.610 x 16.380 x 12.240        25.61       16.38        12.24    blue
# 21  23.710 x 12.770 x 10.890        23.71       12.77        10.89    blue
# 22  21.790 x 12.200 x 10.120        21.79       12.20        10.12    blue
# 24   14.100 x 14.100 x 7.250        14.10       14.10         7.25    blue
# 25     8.830 x 7.350 x 6.380         8.83        7.35         6.38  orange
#
#    Gem_type  Weight (cts) Certified Gemstones     Treatment Clarity     Type  \
# 15    topaz         21.25                 NaN    Irradiated     VVS  Faceted
# 16    topaz         24.56                 NaN    Irradiated     VVS  Faceted
# 17    topaz         37.61                 NaN    Irradiated     VVS  Faceted
# 18    topaz         27.91                 NaN    Irradiated     VVS  Faceted
# 19    topaz         29.78                 NaN    Irradiated     VVS  Faceted
# 20    topaz         38.23                 NaN    Irradiated     VVS  Faceted
# 21    topaz         23.07                 NaN    Irradiated     VVS  Faceted
# 22    topaz         20.36                 NaN    Irradiated     VVS  Faceted
# 24   zircon         12.41                 NaN           NaN      VS  Faceted
# 25   garnet          3.84                 NaN  No Treatment      VS  Faceted
#
#        Shape   Price  Estimated RRP
# 15   Cushion   170.0          299.0
# 16      Pear   199.0          399.0
# 17      Pear   300.0          499.0
# 18      Pear   225.0          399.0
# 19      Pear   240.0          449.0
# 20      Pear   305.0          499.0
# 21      Pear   189.0          249.0
# 22      Pear   165.0          249.0
# 24  Triangle  1150.0         2500.0
# 25      Oval   190.0            NaN

# %% [markdown]
# ### Imputing null values in the Estimated RRP column using interpolation

# %%
dfprice_rrp = df[['Price', 'Estimated RRP']]
dfprice_rrp = dfprice_rrp.interpolate()

# %%
df[['Price', 'Estimated RRP']] = dfprice_rrp
df['Estimated RRP'] = df['Estimated RRP'].round(2)
df.head(10)
# Out:
#                                                 Title  \
# 15  21.25 Cts Natural Swiss Blue Topaz Cushion Cut...
# 16    24.56 Cts Natural Swiss Blue Topaz Pear Cut USA
# 17    37.61 Cts Natural Swiss Blue Topaz Pear Cut USA
# 18    27.91 Cts Natural Swiss Blue Topaz Pear Cut USA
# 19    29.78 Cts Natural Swiss Blue Topaz Pear Cut USA
# 20    38.27 Cts Natural Swiss Blue Topaz Pear Cut USA
# 21    23.07 Cts Natural Swiss Blue Topaz Pear Cut USA
# 22    20.36 Cts Natural Swiss Blue Topaz Pear Cut USA
# 24  12.41 Cts Dazzling Natural Blue - Zircon - Cam...
# 25  3.84 Cts Fanta Orange Natural Spessartite Garn...
#
#               Dimension (mm)  Length (mm)  Width (mm)  Height (mm)   Color  \
# 15  14.620 x 13.680 x 11.910        14.62       13.68        11.91    blue
# 16  21.640 x 14.000 x 10.980        21.64       14.00        10.98    blue
# 17  19.780 x 18.050 x 13.930        19.78       18.05        13.93    blue
# 18  25.560 x 13.790 x 10.520        25.56       13.79        10.52    blue
# 19  25.500 x 14.800 x 10.850        25.50       14.80        10.85    blue
# 20  25.610 x 16.380 x 12.240        25.61       16.38        12.24    blue
# 21  23.710 x 12.770 x 10.890        23.71       12.77        10.89    blue
# 22  21.790 x 12.200 x 10.120        21.79       12.20        10.12    blue
# 24   14.100 x 14.100 x 7.250        14.10       14.10         7.25    blue
# 25     8.830 x 7.350 x 6.380         8.83        7.35         6.38  orange
#
#    Gem_type  Weight (cts) Certified Gemstones     Treatment Clarity     Type  \
# 15    topaz         21.25                 NaN    Irradiated     VVS  Faceted
# 16    topaz         24.56                 NaN    Irradiated     VVS  Faceted
# 17    topaz         37.61                 NaN    Irradiated     VVS  Faceted
# 18    topaz         27.91                 NaN    Irradiated     VVS  Faceted
# 19    topaz         29.78                 NaN    Irradiated     VVS  Faceted
# 20    topaz         38.23                 NaN    Irradiated     VVS  Faceted
# 21    topaz         23.07                 NaN    Irradiated     VVS  Faceted
# 22    topaz         20.36                 NaN    Irradiated     VVS  Faceted
# 24   zircon         12.41                 NaN           NaN      VS  Faceted
# 25   garnet          3.84                 NaN  No Treatment      VS  Faceted
#
#        Shape   Price  Estimated RRP
# 15   Cushion   170.0          299.0
# 16      Pear   199.0          399.0
# 17      Pear   300.0          499.0
# 18      Pear   225.0          399.0
# 19      Pear   240.0          449.0
# 20      Pear   305.0          499.0
# 21      Pear   189.0          249.0
# 22      Pear   165.0          249.0
# 24  Triangle  1150.0         2500.0
# 25      Oval   190.0         1425.0

# %%
df.head(60)
# Out:
#                                                  Title  \
# 15   21.25 Cts Natural Swiss Blue Topaz Cushion Cut...
# 16     24.56 Cts Natural Swiss Blue Topaz Pear Cut USA
# 17     37.61 Cts Natural Swiss Blue Topaz Pear Cut USA
# 18     27.91 Cts Natural Swiss Blue Topaz Pear Cut USA
# 19     29.78 Cts Natural Swiss Blue Topaz Pear Cut USA
# 20     38.27 Cts Natural Swiss Blue Topaz Pear Cut USA
# 21     23.07 Cts Natural Swiss Blue Topaz Pear Cut USA
# 22     20.36 Cts Natural Swiss Blue Topaz Pear Cut USA
# 24   12.41 Cts Dazzling Natural Blue - Zircon - Cam...
# 25   3.84 Cts Fanta Orange Natural Spessartite Garn...
# 26   23.82 Cts Natural Prasiolite(Green Amethyst ) ...
# 27   22.48 Cts Natural Prasiolite(Green Amethyst ) ...
# 28   29.30 Cts Natural Prasiolite(Green Amethyst ) ...
# 31   Amazing Color 1.72 Cts Natural Aquamarine Bagu...
# 32   Excellent Color 1.88 Cts Natural Aquamarine Ba...
# 33   Beautiful Color 3.10 Cts Natural Aquamarine Ba...
# 34   Exquisite Color 3.50 Cts Natural Aquamarine Ba...
# 35   Amazing Color 4.16 Cts Natural Aquamarine Bagu...
# 36   1.50 Cts Color Change Natural Malaya Garnet Tr...
# 37   1.56 Cts Color Change Natural Malaya Garnet Ro...
# 38   1.73 Cts Color Change Natural Malaya Drop Cut ...
# 39   1.58 Cts Color Change Natural Malaya Garnet Cu...
# 40   1.79 Cts Color Change Natural Malaya Garnet Sc...
# 41   2.07 Cts Color Change Natural Malaya Garnet Tr...
# 42   Stunning Color 9.43 Cts Natural Golden Zircon ...
# 43   Pretty Color 8.59 Cts Natural Golden Zircon Ni...
# 44   ~BEAUTIFUL~ 28.03 Cts Natural Parrot Green Per...
# 45   ~BEAUTIFUL~ 25.87 Cts Natural Parrot Green Per...
# 46   ~BEAUTIFUL~21.56 Cts Natural Parrot Green Peri...
# 47   ~BEAUTIFUL~19.89 Cts Natural Parrot Green Peri...
# 48   ~ 15.80  Cts Natural Purple Amethyst Cushion C...
# 51   ~CUSTOM CUT~ 20.66   Cts Natural Purple Amethy...
# 52   ~CUSTOM CUT~ 16.20  Cts Natural Purple Amethys...
# 53   ~ 31.67  Cts Natural Purple Amethyst Octagon C...
# 54   ~ 20.35   Cts Natural Purple Amethyst Octagon ...
# 55   ~ 23.05  Cts Natural Purple Amethyst Cushion C...
# 57   ~  16.25 Cts Natural Purple Amethyst Cushion C...
# 58   ~ 16.06   Cts Natural Purple Amethyst Pear Cut...
# 59   ~ 18.40  Cts Natural Purple Amethyst Pear Cut ...
# 60   ~ 17.59   Cts Natural Purple Amethyst Pear Cut...
# 61   ~ 20.39  Cts Natural Purple Amethyst Pear Cut ...
# 63   CERTIFIED3.18 Cts SPECTACULAR NATURAL MINT GRE...
# 64   1.60 Cts Stunning Natural Blue Heart Spinel Sr...
# 67   ~UNTREATED~ 2.32 Cts Natural Color Change Garn...
# 69   ~UNTREATED~ 1.91 Cts Natural Color Change Garn...
# 70   ~UNTREATED~ 2.15 Cts Natural Color Change Garn...
# 71   ~UNTREATED~ 2.41 Cts Natural Color Change Garn...
# 73   Certified 11.36 Cts Beautiful Natural Sapphire...
# 77   Cute Heart 34.14 Cts Dazzling Natural Morganit...
# 78   Fabulous Color 33.70 Cts Natural Morganite Pea...
# 79   4.31 Cts Natural Purple Spinel Octagon Sri Lan...
# 88   8.18 Cts Beautiful Natural Yellow Tourmaline O...
# 91   2.12 Cts Natural Beautiful Green Emerald Cushi...
# 92   ~SWEET PINK~ 92.24Cts Natural Kunzite Square A...
# 97   4.83 Cts Natural Beautiful Green Emerald Caboc...
# 98   11.95 Cts Natural Top Santa maria Blue Aquamar...
# 100  Glittering Color 8.30 Cts Natural Golden Scapo...
# 102  6.28 Cts Natural Beautiful Green Emerald Cushi...
# 103  0.78 Cts Natural Mexican Fire Opal Fiery Orang...
# 104  0.30 Cts Natural Demantoid Garnet Green Round ...
#
#                Dimension (mm)  Length (mm)  Width (mm)  Height (mm)    Color  \
# 15   14.620 x 13.680 x 11.910        14.62       13.68        11.91     blue
# 16   21.640 x 14.000 x 10.980        21.64       14.00        10.98     blue
# 17   19.780 x 18.050 x 13.930        19.78       18.05        13.93     blue
# 18   25.560 x 13.790 x 10.520        25.56       13.79        10.52     blue
# 19   25.500 x 14.800 x 10.850        25.50       14.80        10.85     blue
# 20   25.610 x 16.380 x 12.240        25.61       16.38        12.24     blue
# 21   23.710 x 12.770 x 10.890        23.71       12.77        10.89     blue
# 22   21.790 x 12.200 x 10.120        21.79       12.20        10.12     blue
# 24    14.100 x 14.100 x 7.250        14.10       14.10         7.25     blue
# 25      8.830 x 7.350 x 6.380         8.83        7.35         6.38   orange
# 26   25.000 x 17.500 x 11.800        25.00       17.50        11.80    green
# 27   20.000 x 15.300 x 12.800        20.00       15.30        12.80    green
# 28   24.900 x 17.200 x 15.100        24.90       17.20        15.10    green
# 31      7.200 x 6.100 x 5.000         7.20        6.10         5.00  natural
# 32     10.000 x 5.600 x 4.100        10.00        5.60         4.10  natural
# 33     16.500 x 5.200 x 4.300        16.50        5.20         4.30  natural
# 34     13.000 x 6.200 x 5.300        13.00        6.20         5.30  natural
# 35     20.000 x 5.300 x 4.500        20.00        5.30         4.50  natural
# 36      7.000 x 7.000 x 4.330         7.00        7.00         4.33  natural
# 37      6.630 x 6.630 x 4.800         6.63        6.63         4.80  natural
# 38      6.830 x 6.590 x 5.150         6.83        6.59         5.15  natural
# 39      6.630 x 6.580 x 4.210         6.63        6.58         4.21  natural
# 40      8.010 x 5.510 x 3.690         8.01        5.51         3.69  natural
# 41      7.170 x 7.240 x 5.320         7.17        7.24         5.32  natural
# 42    14.030 x 12.250 x 6.600        14.03       12.25         6.60  natural
# 43     10.870 x 9.550 x 7.570        10.87        9.55         7.57  natural
# 44   16.210 x 15.980 x 13.300        16.21       15.98        13.30    green
# 45   18.890 x 14.450 x 10.320        18.89       14.45        10.32    green
# 46   15.550 x 13.610 x 12.870        15.55       13.61        12.87    green
# 47    16.540 x 16.500 x 9.830        16.54       16.50         9.83    green
# 48   18.230 x 12.400 x 10.290        18.23       12.40        10.29   purple
# 51   21.600 x 15.000 x 10.220        21.60       15.00        10.22   purple
# 52   20.220 x 18.730 x 10.360        20.22       18.73        10.36   purple
# 53   24.510 x 15.210 x 12.650        24.51       15.21        12.65   purple
# 54   15.400 x 14.390 x 13.850        15.40       14.39        13.85   purple
# 55   22.270 x 15.360 x 10.900        22.27       15.36        10.90   purple
# 57    18.840 x 13.910 x 9.310        18.84       13.91         9.31   purple
# 58   20.910 x 11.830 x 12.030        20.91       11.83        12.03   purple
# 59   18.800 x 16.960 x 11.300        18.80       16.96        11.30   purple
# 60   19.690 x 13.690 x 11.810        19.69       13.69        11.81   purple
# 61   21.710 x 16.010 x 11.000        21.71       16.01        11.00   purple
# 63      8.860 x 8.340 x 5.010         8.86        8.34         5.01    green
# 64      7.690 x 7.170 x 4.260         7.69        7.17         4.26     blue
# 67      8.110 x 6.570 x 4.810         8.11        6.57         4.81  natural
# 69     10.050 x 6.390 x 3.720        10.05        6.39         3.72  natural
# 70     10.520 x 6.530 x 3.980        10.52        6.53         3.98  natural
# 71     10.350 x 6.610 x 4.130        10.35        6.61         4.13  natural
# 73    12.510 x 13.130 x 8.360        12.51       13.13         8.36     blue
# 77   22.300 x 20.500 x 13.800        22.30       20.50        13.80     pink
# 78   24.000 x 18.700 x 13.000        24.00       18.70        13.00     pink
# 79      9.500 x 7.600 x 5.600         9.50        7.60         5.60   purple
# 88    12.400 x 10.400 x 9.000        12.40       10.40         9.00   yellow
# 91      8.040 x 6.780 x 5.080         8.04        6.78         5.08    green
# 92     10.000 x 8.000 x 7.000        10.00        8.00         7.00     pink
# 97    10.710 x 11.000 x 6.850        10.71       11.00         6.85    green
# 98    13.710 x 12.020 x 9.050        13.71       12.02         9.05     blue
# 100   11.000 x 11.000 x 7.020        11.00       11.00         7.02  natural
# 102   10.630 x 10.580 x 6.970        10.63       10.58         6.97    green
# 103     7.860 x 5.810 x 3.780         7.86        5.81         3.78   orange
# 104     2.440 x 2.440 x 1.570         2.44        2.44         1.57    green
#
#               Gem_type  Weight (cts) Certified Gemstones       Treatment  \
# 15               topaz         21.25                 NaN      Irradiated
# 16               topaz         24.56                 NaN      Irradiated
# 17               topaz         37.61                 NaN      Irradiated
# 18               topaz         27.91                 NaN      Irradiated
# 19               topaz         29.78                 NaN      Irradiated
# 20               topaz         38.23                 NaN      Irradiated
# 21               topaz         23.07                 NaN      Irradiated
# 22               topaz         20.36                 NaN      Irradiated
# 24              zircon         12.41                 NaN             NaN
# 25              garnet          3.84                 NaN    No Treatment
# 26            amethyst         23.82                 NaN    No Treatment
# 27            amethyst         22.48                 NaN  Heat Treatment
# 28            amethyst         29.30                 NaN  Heat Treatment
# 31          aquamarine          1.72                 NaN    No Treatment
# 32          aquamarine          1.88                 NaN    No Treatment
# 33          aquamarine          3.10                 NaN    No Treatment
# 34          aquamarine          3.50                 NaN    No Treatment
# 35          aquamarine          4.16                 NaN    No Treatment
# 36              garnet          1.50                 NaN    No Treatment
# 37              garnet          1.56                 NaN    No Treatment
# 38                  na          1.73                 NaN    No Treatment
# 39              garnet          1.58                 NaN    No Treatment
# 40              garnet          1.79                 NaN    No Treatment
# 41              garnet          2.07                 NaN    No Treatment
# 42              zircon          5.11                 NaN    No Treatment
# 43             emerald          8.59                 NaN    No Treatment
# 44             peridot         28.03                 NaN    No Treatment
# 45             peridot         25.87                 NaN    No Treatment
# 46             peridot         21.56                 NaN    No Treatment
# 47             peridot         19.89                 NaN    No Treatment
# 48            amethyst         15.80                 NaN    No Treatment
# 51            amethyst         20.66                 NaN    No Treatment
# 52            amethyst         16.20                 NaN    No Treatment
# 53            amethyst         31.67                 NaN    No Treatment
# 54            amethyst         20.35                 NaN    No Treatment
# 55            amethyst         23.05                 NaN    No Treatment
# 57            amethyst         16.25                 NaN    No Treatment
# 58            amethyst         16.06                 NaN    No Treatment
# 59            amethyst         18.40                 NaN    No Treatment
# 60            amethyst         17.59                 NaN    No Treatment
# 61            amethyst         20.39                 NaN    No Treatment
# 63          tourmaline          3.18                 Yes    No Treatment
# 64              spinel          1.60                 NaN    No Treatment
# 67              garnet          2.32                 NaN    No Treatment
# 69              garnet          1.91                 NaN    No Treatment
# 70              garnet          2.15                 NaN    No Treatment
# 71              garnet          2.41                 NaN    No Treatment
# 73            sapphire         11.36                 Yes    No Treatment
# 77           morganite         34.14                 NaN    No Treatment
# 78           morganite         33.70                 NaN    No Treatment
# 79              spinel          4.31                 NaN    No Treatment
# 88          tourmaline          8.18                 NaN    No Treatment
# 91             emerald          2.12                 NaN             NaN
# 92             kunzite         92.24                 NaN  Heat Treatment
# 97             emerald          4.83                 NaN             NaN
# 98          aquamarine         11.95                 NaN    No Treatment
# 100          scapolite          8.30                 NaN    No Treatment
# 102            emerald          6.28                 NaN             NaN
# 103  mexican fire opal          0.78                 NaN    No Treatment
# 104             garnet          0.30                 NaN             NaN
#
#     Clarity      Type                            Shape    Price  Estimated RRP
# 15      VVS   Faceted                          Cushion   170.00         299.00
# 16      VVS   Faceted                             Pear   199.00         399.00
# 17      VVS   Faceted                             Pear   300.00         499.00
# 18      VVS   Faceted                             Pear   225.00         399.00
# 19      VVS   Faceted                             Pear   240.00         449.00
# 20      VVS   Faceted                             Pear   305.00         499.00
# 21      VVS   Faceted                             Pear   189.00         249.00
# 22      VVS   Faceted                             Pear   165.00         249.00
# 24       VS   Faceted                         Triangle  1150.00        2500.00
# 25       VS   Faceted                             Oval   190.00        1425.00
# 26      VVS   Faceted                            Fancy    99.00         350.00
# 27      NaN   Faceted                             Oval    88.88         257.50
# 28       VS   Faceted                      Fancy, Pear   125.00         165.00
# 31       VS   Faceted                         Baguette    75.00         867.43
# 32       VS   Faceted                         Baguette    85.00        1569.86
# 33       VS   Faceted                         Baguette   140.00        2272.29
# 34       VS   Faceted                         Baguette   155.00        2974.71
# 35       VS   Faceted                         Baguette   185.00        3677.14
# 36       VS   Faceted                        Trilliant    85.00        4379.57
# 37       VS   Faceted                            Round    88.00        5082.00
# 38       VS   Faceted                             Drop    99.00        5784.43
# 39       VS   Faceted                          Cushion    90.00        6486.86
# 40       VS   Faceted               Octagonal, Radiant    99.00        7189.29
# 41       VS   Faceted                        Trilliant   115.00        7891.71
# 42      VVS   Faceted                            Heart   575.00        8594.14
# 43      VVS   Faceted               Emerald, Octagonal   580.00        9296.57
# 44      VVS   Faceted                        Octagonal  4444.00        9999.00
# 45      VVS   Faceted                        Octagonal  3999.00        9999.00
# 46      VVS   Faceted                Octagonal, Square  3333.00        9999.00
# 47      VVS   Faceted                Octagonal, Square  2999.00        9999.00
# 48      VVS   Faceted                          Cushion    85.00         189.00
# 51      VVS   Faceted                            Fancy   105.00         249.00
# 52      VVS   Faceted                            Fancy    85.00         199.00
# 53      VVS   Faceted                        Octagonal   160.00         299.00
# 54      VVS   Faceted                        Octagonal   105.00         249.00
# 55      VVS   Faceted                          Cushion   115.00         199.00
# 57      VVS   Faceted                          Cushion    85.00         199.00
# 58      VVS   Faceted                             Pear    80.00         149.00
# 59      VVS   Faceted                             Pear    95.00         199.00
# 60      VVS   Faceted                             Pear    90.00         199.00
# 61      VVS   Faceted                             Pear   105.00         199.00
# 63      NaN   Faceted                        Octagonal   475.00         999.00
# 64       VS   Faceted                            Heart   225.00         444.00
# 67      NaN   Faceted                             Oval   111.00         999.00
# 69      NaN   Faceted                              NaN    92.00         222.00
# 70      NaN   Faceted                             Pear    99.00         333.00
# 71      NaN   Faceted                              NaN   111.00         444.00
# 73       SI   Faceted                            Heart  2750.00        4444.00
# 77      VVS   Faceted                            Heart  2495.00        4800.00
# 78      VVS   Faceted                             Oval  2450.00        4900.00
# 79       VS   Faceted                        Octagonal   700.00        1450.00
# 88      NaN   Faceted                             Oval   555.00         666.00
# 91      NaN       NaN                              NaN  1111.00        5555.00
# 92      VVS   Faceted  Fancy, Cushion, Radiant, Square  1490.00        2950.00
# 97      NaN       NaN                              NaN  1999.00        8888.00
# 98       VS  Cabochon                             Oval   950.00        1700.00
# 100     VVS   Faceted                            Round   175.00         350.00
# 102     NaN       NaN                              NaN  1999.00        9999.00
# 103     VVS   Faceted                             Oval    15.00          75.00
# 104     NaN       NaN                              NaN   125.00         999.00
