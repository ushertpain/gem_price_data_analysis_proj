# %% [markdown]
# ### import relevant libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('cleaned_gem_price_data.csv')

# %%
data.head()
# Out:
#                                                Title  \
# 0  21.25 Cts Natural Swiss Blue Topaz Cushion Cut...
# 1    24.56 Cts Natural Swiss Blue Topaz Pear Cut USA
# 2    37.61 Cts Natural Swiss Blue Topaz Pear Cut USA
# 3    27.91 Cts Natural Swiss Blue Topaz Pear Cut USA
# 4    29.78 Cts Natural Swiss Blue Topaz Pear Cut USA
#
#              Dimension (mm)  Length (mm)  Width (mm)  Height (mm) Color  \
# 0  14.620 x 13.680 x 11.910        14.62       13.68        11.91  blue
# 1  21.640 x 14.000 x 10.980        21.64       14.00        10.98  blue
# 2  19.780 x 18.050 x 13.930        19.78       18.05        13.93  blue
# 3  25.560 x 13.790 x 10.520        25.56       13.79        10.52  blue
# 4  25.500 x 14.800 x 10.850        25.50       14.80        10.85  blue
#
#   Gem_type  Weight (cts) Certified Gemstones   Treatment  \
# 0    topaz         21.25      None Certified  Irradiated
# 1    topaz         24.56      None Certified  Irradiated
# ...

# %%
data.tail()
# Out:
#                                                   Title  \
# 2395  16.02 Cts Beautiful Natural Amethyst Purple He...
# 2396  33.75 Cts Untreated Natural Green Fluorite Bea...
# 2397  31.45 Cts Untreated Natural Green Fluorite Fan...
# 2398  Awesome 3.82 Cts Natural Sparkling Red Rhodoli...
# 2399  ~CUSTOM CUT~ 22.22Cts Natural Purple Amethyst ...
#
#                 Dimension (mm)  Length (mm)  Width (mm)  Height (mm)   Color  \
# 2395  17.830 x 17.190 x 11.220        17.83       17.19        11.22  purple
# 2396  21.500 x 17.400 x 11.300        21.50       17.40        11.30   green
# 2397  20.100 x 16.300 x 11.700        20.10       16.30        11.70   green
# 2398    11.100 x 8.700 x 4.900        11.10        8.70         4.90     red
# 2399  19.250 x 14.160 x 11.030        19.25       14.16        11.03  purple
#
#       Gem_type  Weight (cts) Certified Gemstones     Treatment  \
# 2395  amethyst         16.02      None Certified  No Treatment
# ...

# %%
data.columns
# Out:
# Index(['Title', 'Dimension (mm)', 'Length (mm)', 'Width (mm)', 'Height (mm)',
#        'Color', 'Gem_type', 'Weight (cts)', 'Certified Gemstones', 'Treatment',
#        'Clarity', 'Type', 'Shape', 'Price', 'Estimated RRP'],
#       dtype='object')

# %%
data.shape
# Out:
# (2400, 15)

# %%
nan_count = data['Type'].isnull().sum()
print(nan_count)
# Out:
# 311

# %%
data['Weight (cts)'].unique()
# Out:
# array([21.25, 24.56, 37.61, ..., 19.96, 16.02, 31.45])
